# %% [markdown]
# <a href="https://colab.research.google.com/github/faijalamia/Machine-Learning/blob/hw/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Bismilla-hi-rahman-er-rahim ")
# Out:
# Bismilla-hi-rahman-er-rahim

# %%
parint("Assalamu alaykum wa rahmatullahi wabarakatu")
# Out:
# Assalamu alaykum wa rahmatullahi wabarakatu
